# %% [markdown]
# ## Content-based Recommender

# %%
# %pip install pandas numpy seaborn matplotlib scipy scikit-learn nltk

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


from scipy import sparse
import ast
from sklearn.metrics.pairwise import cosine_similarity
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pickle
import warnings
warnings.filterwarnings('ignore')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (2.3.2)
# Requirement already satisfied: numpy in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (2.0.2)
# Requirement already satisfied: seaborn in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: matplotlib in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (3.9.4)
# Requirement already satisfied: scipy in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (1.13.1)
# Requirement already satisfied: scikit-learn in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: nltk in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: pillow>=8 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tqdm in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: click in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: zipp>=3.1.0 in /Users/mustafaansari/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
df_main = pd.read_csv('../data/content.csv')
df_main.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genres  year  tmdb_id    imdb_id  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995      862  tt0114709
# 1                   Adventure|Children|Fantasy  1995     8844  tt0113497
# 2                               Comedy|Romance  1995    15602  tt0113228
# 3                         Comedy|Drama|Romance  1995    31357  tt0114885
# 4                                       Comedy  1995    11862  tt0113041
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                              tagline  tmdb_rating  tmdb_votes  \
# 0                                                NaN          7.7      5415.0
# 1          Roll the dice and unleash the excitement!          6.9      2413.0
# 2  Still Yelling. Still Fighting. Still Ready for...          6.5        92.0
# 3  Friends are the people who let you be yourself...          6.1        34.0
# 4  Just When His World Is Back To Normal... He's ...          5.7       173.0
#
#    imdb_rating  imdb_votes                                           keywords  \
# 0          8.3    956821.0  jealousy toy boy friendship friends rivalry bo...
# 1          7.0    334566.0  board game disappearance based on children's b...
# 2          6.6     26930.0   fishing best friend duringcreditsstinger old men
# 3          5.9     10784.0  based on novel interracial relationship single...
# 4          6.0     37433.0  baby midlife crisis confidence aging daughter ...
#
#                                                 cast        director
# 0            TomHanks TimAllen DonRickles JimVarney     JohnLasseter
# 1  RobinWilliams JonathanHyde KirstenDunst Bradle...     JoeJohnston
# 2  WalterMatthau JackLemmon Ann-Margret SophiaLoren     HowardDeutch
# 3  WhitneyHouston AngelaBassett LorettaDevine Lel...  ForestWhitaker
# 4  SteveMartin DianeKeaton MartinShort KimberlyWi...    CharlesShyer

# %%
df_main.shape
# Out:
# (9541, 15)

# %%
df_main.dtypes
# Out:
# movie_id         int64
# title           object
# genres          object
# year             int64
# tmdb_id          int64
# imdb_id         object
# overview        object
# tagline         object
# tmdb_rating    float64
# tmdb_votes     float64
# imdb_rating    float64
# imdb_votes     float64
# keywords        object
# cast            object
# director        object
# dtype: object

# %%
df_main.isnull().sum()
# Out:
# movie_id          0
# title             0
# genres            0
# year              0
# tmdb_id           0
# imdb_id           0
# overview         18
# tagline        2301
# tmdb_rating       0
# tmdb_votes        0
# imdb_rating       0
# imdb_votes        0
# keywords        862
# cast            102
# director         30
# dtype: int64

# %%
df_main.describe()
# Out:
#             movie_id         year        tmdb_id  tmdb_rating    tmdb_votes  \
# count    9541.000000  9541.000000    9541.000000  9541.000000   9541.000000
# mean    39802.225762  1992.859134   49967.332460     6.360706    448.874227
# std     49374.192724    57.074734   84177.669558     1.021580    995.393461
# min         1.000000     0.000000       2.000000     0.000000      0.000000
# 25%      3169.000000  1987.000000    9595.000000     5.800000     33.000000
# 50%      7116.000000  1999.000000   16148.000000     6.400000    105.000000
# 75%     72226.000000  2007.000000   42229.000000     7.000000    378.000000
# max    176051.000000  2017.000000  461805.000000    10.000000  14075.000000
#
#        imdb_rating    imdb_votes
# count  9541.000000  9.541000e+03
# mean      6.635384  7.648837e+04
# std       1.024158  1.584902e+05
# min       0.000000  0.000000e+00
# 25%       6.100000  7.425000e+03
# 50%       6.700000  2.209800e+04
# 75%       7.400000  7.438100e+04
# max       9.500000  2.566477e+06

# %% [markdown]
# From 9541 movies, 2301 movies do not have a tagline. The nulls in this column have been impiuted by blank string. The same has been done for other columns like overview, keywords, cast and director.

# %%
#Converting datatype from float to integer 
df_main['tmdb_votes'] = df_main['tmdb_votes'].map(int)

# %%
#Converting datatype from float to integer 
df_main['imdb_votes'] = df_main['imdb_votes'].map(int)

# %%
df_main['overview'].fillna('', inplace=True)

# %%
df_main['tagline'].fillna('', inplace=True)

# %%
df_main['keywords'].fillna('', inplace=True)

# %%
df_main['cast'].fillna('', inplace=True)

# %%
df_main['director'].fillna('', inplace=True)

# %%
df_main['body'] = df_main['overview'] + ' ' + df_main['tagline']

# %%
df_main['body'] = df_main['body'].str.lower()

# %%
lemmatizer = WordNetLemmatizer()

# %%
#Check lemmatizer
lemmatizer.lemmatize('siblings')
# Out:
# 'sibling'

# %%
#Remove stopwords and clean text
def remove_stop(row):
    clean_row = ''
    for word in row.split():
        if word not in set(stopwords.words('english')):
            #Before stemming a word, match a single character 
            #not present in the list below and replace it
            word = lemmatizer.lemmatize(re.sub('[^a-zA-Z0-9]','', word))
            if len(word)>0:
                clean_row += word + ' '
    return clean_row

# %%
#Remove stop words from the body column
df_main['body'] = df_main['body'].map(remove_stop)

# %%
#Delete overview and tagline columns
df_main.drop(columns=['overview', 'tagline'], inplace=True)

# %% [markdown]
# Used a TF-IDF Vectorizer to vectorize text in movie tagline and synopsis.

# %%
tfidf = TfidfVectorizer(min_df=1, max_df=0.9)
tfidf_matrix = tfidf.fit_transform(df_main['body'])

# %%
#Calculate similarity score
similarity_plot = cosine_similarity(sparse.csr_matrix(tfidf_matrix))

# %% [markdown]
# Make recommendations for movie `Godfather`.

# %%
movie_name = 'Godfather'
index = df_main[df_main['title'].str.contains(movie_name)].index[0]
result = df_main.loc[[val for val in np.argsort(similarity_plot[index])[::-1][1:10]]]
result
# Out:
#       movie_id                                    title  \
# 919       1221           Godfather: Part II, The (1974)
# 9489    172591  The Godfather Trilogy: 1972-1990 (1992)
# 1495      2023          Godfather: Part III, The (1990)
# 3286      4452                              Made (2001)
# 3942      5568                Johnny Dangerously (1984)
# 4597      6860                          Mobsters (1991)
# 5341      8918                            Eulogy (2004)
# 2161      2881                   Double Jeopardy (1999)
# 7548     86028                     Henry's Crime (2010)
#
#                             genres  year  tmdb_id    imdb_id  tmdb_rating  \
# 919                    Crime|Drama  1974      240  tt0071562          8.3
# 9489            (no genres listed)  1992   364150  tt0150742          8.8
# 1495  Crime|Drama|Mystery|Thriller  1990      242  tt0099674          7.1
# 3286                        Comedy  2001    15745  tt0227005          6.3
# 3942                        Comedy  1984    16806  tt0087507          6.3
# 4597                   Crime|Drama  1991    21219  tt0102460          5.7
# 5341            Comedy|Crime|Drama  2004    16358  tt0349416          6.4
# 2161   Action|Crime|Drama|Thriller  1999    10398  tt0150377          6.2
# 7548                  Comedy|Crime  2010    53172  tt1220888          5.8
#
#       tmdb_votes  imdb_rating  imdb_votes  \
# 919         3418          9.0     1222540
# 9489          13          9.3       15685
# 1495        1589          7.6      385137
# 3286          55          6.3       18430
# 3942          67          6.5       14476
# 4597          34          5.9        9065
# 5341          34          6.5        8989
# 2161         282          6.5       84960
# 7548         110          5.9       20170
#
#                                                keywords  \
# 919   italo-american cuba vororte melancholy praise ...
# 9489
# 1495  italy christianity new york assassination ital...
# 3286
# 3942             organized crime mobster woman director
# 4597               historical figure mafia boss mobster
# 5341  family secrets dysfunctional family independen...
# 2161  prison sailboat sailing trip new orleans women...
# 7548                               vomit food poisoning
#
#                                                    cast             director  \
# 919     AlPacino RobertDuvall DianeKeaton RobertDeNiro    FrancisFordCoppola
# 9489
# 1495        AlPacino DianeKeaton AndyGarcía TaliaShire    FrancisFordCoppola
# 3286     VinceVaughn JonFavreau SeanCombs FamkeJanssen            JonFavreau
# 3942  MichaelKeaton PeterBoyle GriffinDunne MariluHe...        AmyHeckerling
# 4597  ChristianSlater CostasMandylor RichardGrieco P...  MichaelKarbelnikoff
# 5341  HankAzaria JesseBradford ZooeyDeschanel Glenne...        MichaelClancy
# 2161  TommyLeeJones AshleyJudd BruceGreenwood Annabe...       BruceBeresford
# 7548       KeanuReeves VeraFarmiga JamesCaan JudyGreer       MalcolmVenville
#
#                                                    body
# 919   continuing saga corleone crime family young vi...
# 9489  multigenerational saga rise fall corleone crim...
# 1495  midst trying legitimize business dealing 1979 ...
# 3286  two aspiring boxer lifelong friend get involve...
# 3942  set 1930s honest goodhearted man forced turn l...
# 4597  story group friend turn century new york early...
# 5341  black comedy follows three generation family c...
# 2161  woman framed husband murder suspect still aliv...
# 7548  aimless man sent prison crime commit real crim...

# %% [markdown]
# This basic recommender filters movies based on `tagline` and `overview` of the movie. `Godfather` is a crime & drama movie. The recommender filtered *mafia* movies but also suggested `Made` & `Johnny Dangerously`. Johnny Dangerouslly is a comedy mafia movie but Made is not related. More features must be considered to enhance the recommender.

# %% [markdown]
# ### Additional Movie Features

# %% [markdown]
# This section is dedicated to addidng features like `keywords`, `director` and `cast`.

# %%
df_main['body'] = df_main['body'] + ' ' + df_main['keywords']

# %% [markdown]
# Use the `remove_stop` function created before to remove English stop words, lowercase and lemmatize the text.

# %%
df_main['body'] = df_main['body'].map(remove_stop)

# %% [markdown]
# Since the contents of column `keywords` have been cleaned and combined in the `body` column, it can be deleted from the dataframe.

# %%
df_main.drop(columns=['keywords'], inplace=True)

# %% [markdown]
# Vectorizing `overview`, `tagline` and `keywords` combines in the column `body`.

# %%
tfidf = TfidfVectorizer(min_df=1, max_df = 0.9)
tfidf_matrix = tfidf.fit_transform(df_main['body'])
#Calculate cosine similarity 
similarity_keywords = cosine_similarity(sparse.csr_matrix(tfidf_matrix))

# %%
movie_name = 'Godfather'
index = df_main[df_main['title'].str.contains(movie_name)].index[0]
result = df_main.loc[[val for val in np.argsort(similarity_keywords[index])[::-1][1:10]]]
result
# Out:
#       movie_id                                    title  \
# 919       1221           Godfather: Part II, The (1974)
# 9489    172591  The Godfather Trilogy: 1972-1990 (1992)
# 3942      5568                Johnny Dangerously (1984)
# 4597      6860                          Mobsters (1991)
# 1495      2023          Godfather: Part III, The (1990)
# 3286      4452                              Made (2001)
# 5341      8918                            Eulogy (2004)
# 8228    104925                       Family, The (2013)
# 911       1213                        Goodfellas (1990)
#
#                             genres  year  tmdb_id    imdb_id  tmdb_rating  \
# 919                    Crime|Drama  1974      240  tt0071562          8.3
# 9489            (no genres listed)  1992   364150  tt0150742          8.8
# 3942                        Comedy  1984    16806  tt0087507          6.3
# 4597                   Crime|Drama  1991    21219  tt0102460          5.7
# 1495  Crime|Drama|Mystery|Thriller  1990      242  tt0099674          7.1
# 3286                        Comedy  2001    15745  tt0227005          6.3
# 5341            Comedy|Crime|Drama  2004    16358  tt0349416          6.4
# 8228           Action|Comedy|Crime  2013   112205  tt2404311          6.1
# 911                    Crime|Drama  1990      769  tt0099685          8.2
#
#       tmdb_votes  imdb_rating  imdb_votes  \
# 919         3418          9.0     1222540
# 9489          13          9.3       15685
# 3942          67          6.5       14476
# 4597          34          5.9        9065
# 1495        1589          7.6      385137
# 3286          55          6.3       18430
# 5341          34          6.5        8989
# 8228        1052          6.3      115510
# 911         3211          8.7     1107550
#
#                                                    cast             director  \
# 919     AlPacino RobertDuvall DianeKeaton RobertDeNiro    FrancisFordCoppola
# 9489
# 3942  MichaelKeaton PeterBoyle GriffinDunne MariluHe...        AmyHeckerling
# 4597  ChristianSlater CostasMandylor RichardGrieco P...  MichaelKarbelnikoff
# 1495        AlPacino DianeKeaton AndyGarcía TaliaShire    FrancisFordCoppola
# 3286     VinceVaughn JonFavreau SeanCombs FamkeJanssen            JonFavreau
# 5341  HankAzaria JesseBradford ZooeyDeschanel Glenne...        MichaelClancy
# 8228  RobertDeNiro MichellePfeiffer DiannaAgron John...            LucBesson
# 911     RobertDeNiro RayLiotta JoePesci LorraineBracco        MartinScorsese
#
#                                                    body
# 919   continuing saga corleone crime family young vi...
# 9489  multigenerational saga rise fall corleone crim...
# 3942  set 1930s honest goodhearted man forced turn l...
# 4597  story group friend turn century new york early...
# 1495  midst trying legitimize business dealing 1979 ...
# 3286  two aspiring boxer lifelong friend get involve...
# 5341  black comedy follows three generation family c...
# 8228  manzoni family notorious mafia clan relocated ...
# 911   true story henry hill halfirish halfsicilian b...

# %% [markdown]
# An important feature considered by user while choosing a movie is the `director` and `cast`.

# %%
df_main['body'] = df_main['body'] + ' ' + df_main['director'] + ' ' + df_main['cast']

# %%
df_main.drop(columns=['director', 'cast'], inplace=True)

# %%
df_main.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genres  year  tmdb_id    imdb_id  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995      862  tt0114709
# 1                   Adventure|Children|Fantasy  1995     8844  tt0113497
# 2                               Comedy|Romance  1995    15602  tt0113228
# 3                         Comedy|Drama|Romance  1995    31357  tt0114885
# 4                                       Comedy  1995    11862  tt0113041
#
#    tmdb_rating  tmdb_votes  imdb_rating  imdb_votes  \
# 0          7.7        5415          8.3      956821
# 1          6.9        2413          7.0      334566
# 2          6.5          92          6.6       26930
# 3          6.1          34          5.9       10784
# 4          5.7         173          6.0       37433
#
#                                                 body
# 0  led woody andys toy live happily room andys bi...
# 1  sibling judy peter discover enchanted board ga...
# 2  family wedding reignites ancient feud nextdoor...
# 3  cheated mistreated stepped woman holding breat...
# 4  george bank recovered daughter wedding receive...

# %% [markdown]
# The next feature that plays an important role in a user's movie selection is the movie `genre`.

# %%
df_main['genres_text'] = df_main['genres'].map(lambda x: (' '.join(x.split('|'))).lower())

# %%
df_main['body'] = df_main['body'] + ' ' + df_main['genres_text']

# %%
df_main.drop(columns=['genres_text'], inplace=True)

# %%
df_main.head()
# Out:
#    movie_id                               title  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genres  year  tmdb_id    imdb_id  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995      862  tt0114709
# 1                   Adventure|Children|Fantasy  1995     8844  tt0113497
# 2                               Comedy|Romance  1995    15602  tt0113228
# 3                         Comedy|Drama|Romance  1995    31357  tt0114885
# 4                                       Comedy  1995    11862  tt0113041
#
#    tmdb_rating  tmdb_votes  imdb_rating  imdb_votes  \
# 0          7.7        5415          8.3      956821
# 1          6.9        2413          7.0      334566
# 2          6.5          92          6.6       26930
# 3          6.1          34          5.9       10784
# 4          5.7         173          6.0       37433
#
#                                                 body
# 0  led woody andys toy live happily room andys bi...
# 1  sibling judy peter discover enchanted board ga...
# 2  family wedding reignites ancient feud nextdoor...
# 3  cheated mistreated stepped woman holding breat...
# 4  george bank recovered daughter wedding receive...

# %%
df_main.shape
# Out:
# (9541, 11)

# %% [markdown]
# Vectorize `overview`, `tagline`, `keywords`, `director`, `cast` and `genre` all combined in the `body` column using TF-IDF.

# %%
tfidf = TfidfVectorizer(min_df=1, max_df = .85)
tfidf_matrix = tfidf.fit_transform(df_main['body'])
similarity_cast = cosine_similarity(sparse.csc_matrix(tfidf_matrix))

# %%
similarity_cast.shape
# Out:
# (9541, 9541)

# %%
movie_name = 'Godfather'
index = df_main[df_main['title'].str.contains(movie_name)].index[0]
result = df_main.loc[[val for val in np.argsort(similarity_cast[index])[::-1][1:10]]]
result
# Out:
#       movie_id                                    title  \
# 919       1221           Godfather: Part II, The (1974)
# 9489    172591  The Godfather Trilogy: 1972-1990 (1992)
# 1495      2023          Godfather: Part III, The (1990)
# 5341      8918                            Eulogy (2004)
# 3942      5568                Johnny Dangerously (1984)
# 4597      6860                          Mobsters (1991)
# 8228    104925                       Family, The (2013)
# 911       1213                        Goodfellas (1990)
# 6539     55036                             Gotti (1996)
#
#                             genres  year  tmdb_id    imdb_id  tmdb_rating  \
# 919                    Crime|Drama  1974      240  tt0071562          8.3
# 9489            (no genres listed)  1992   364150  tt0150742          8.8
# 1495  Crime|Drama|Mystery|Thriller  1990      242  tt0099674          7.1
# 5341            Comedy|Crime|Drama  2004    16358  tt0349416          6.4
# 3942                        Comedy  1984    16806  tt0087507          6.3
# 4597                   Crime|Drama  1991    21219  tt0102460          5.7
# 8228           Action|Comedy|Crime  2013   112205  tt2404311          6.1
# 911                    Crime|Drama  1990      769  tt0099685          8.2
# 6539                   Crime|Drama  1996    14786  tt0116441          5.1
#
#       tmdb_votes  imdb_rating  imdb_votes  \
# 919         3418          9.0     1222540
# 9489          13          9.3       15685
# 1495        1589          7.6      385137
# 5341          34          6.5        8989
# 3942          67          6.5       14476
# 4597          34          5.9        9065
# 8228        1052          6.3      115510
# 911         3211          8.7     1107550
# 6539          12          7.2        7399
#
#                                                    body
# 919   continuing saga corleone crime family young vi...
# 9489  multigenerational saga rise fall corleone crim...
# 1495  midst trying legitimize business dealing 1979 ...
# 5341  black comedy follows three generation family c...
# 3942  set 1930s honest goodhearted man forced turn l...
# 4597  story group friend turn century new york early...
# 8228  manzoni family notorious mafia clan relocated ...
# 911   true story henry hill halfirish halfsicilian b...
# 6539  john gotti head small new york mafia crew brea...

# %% [markdown]
# The above recommedations are more in similar to the movie `Godfather` than any of the recommendations obtained before. The following code adds the feature of polarity score to the recommender.

# %% [markdown]
# ### Sentiment Analysis

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores(df_main['body'].values[0])
# Out:
# {'neg': 0.071, 'neu': 0.72, 'pos': 0.209, 'compound': 0.8625}

# %% [markdown]
# Compound polarity score has been used in the recommender.

# %%
df_main['sentiment_score'] = df_main['body'].map(lambda x: sia.polarity_scores(x)['compound'])

# %%
plt.figure(figsize=(8,6))
sns.displot(df_main['sentiment_score'], bins=50, color='#582f9a')
plt.xlabel('Polarity Score')
plt.ylabel('Count')
plt.title('Sentiment Analysis of Movie Content')
plt.savefig('../images/sentiment_analysis', facecolor='w', transparent=False, dpi = 1000, bbox_inches='tight');

# %% [markdown]
# Vectorizing the `body` column of the dataframe and combining sentiment analysis scores column and vetorized columns to calculate cosine similarity between the movies.

# %%
tfidf = TfidfVectorizer(min_df=1, max_df=0.85)

tfidf_matrix = tfidf.fit_transform(df_main['body'])

tfidf_df = pd.DataFrame(
    tfidf_matrix.todense(),
    columns=tfidf.get_feature_names_out()
)

# %%
#Combine vectorized columns with sentiment analysis column
df_vect = pd.concat([tfidf_df, 0.2 * df_main['sentiment_score']], axis=1)

# %% [markdown]
# The vectorized matrix was turned into a dense matrix for concatenation. It has been converted back to sparse matrix to calculate similarity.

# %%
similarity = cosine_similarity(sparse.csr_matrix(df_vect))

# %%
movie_name = 'Godfather'
index = df_main[df_main['title'].str.contains(movie_name)].index[0]
result = df_main.loc[[val for val in np.argsort(similarity[index])[::-1][1:11]]]
result
# Out:
#       movie_id                                    title  \
# 919       1221           Godfather: Part II, The (1974)
# 9489    172591  The Godfather Trilogy: 1972-1990 (1992)
# 1495      2023          Godfather: Part III, The (1990)
# 5341      8918                            Eulogy (2004)
# 3942      5568                Johnny Dangerously (1984)
# 4597      6860                          Mobsters (1991)
# 8228    104925                       Family, The (2013)
# 911       1213                        Goodfellas (1990)
# 6539     55036                             Gotti (1996)
# 8889    136018                        Black Mass (2015)
#
#                             genres  year  tmdb_id    imdb_id  tmdb_rating  \
# 919                    Crime|Drama  1974      240  tt0071562          8.3
# 9489            (no genres listed)  1992   364150  tt0150742          8.8
# 1495  Crime|Drama|Mystery|Thriller  1990      242  tt0099674          7.1
# 5341            Comedy|Crime|Drama  2004    16358  tt0349416          6.4
# 3942                        Comedy  1984    16806  tt0087507          6.3
# 4597                   Crime|Drama  1991    21219  tt0102460          5.7
# 8228           Action|Comedy|Crime  2013   112205  tt2404311          6.1
# 911                    Crime|Drama  1990      769  tt0099685          8.2
# 6539                   Crime|Drama  1996    14786  tt0116441          5.1
# 8889                   Crime|Drama  2015   261023  tt1355683          6.3
#
#       tmdb_votes  imdb_rating  imdb_votes  \
# 919         3418          9.0     1222540
# 9489          13          9.3       15685
# 1495        1589          7.6      385137
# 5341          34          6.5        8989
# 3942          67          6.5       14476
# 4597          34          5.9        9065
# 8228        1052          6.3      115510
# 911         3211          8.7     1107550
# 6539          12          7.2        7399
# 8889        1262          6.9      177066
#
#                                                    body  sentiment_score
# 919   continuing saga corleone crime family young vi...          -0.9300
# 9489  multigenerational saga rise fall corleone crim...          -0.5423
# 1495  midst trying legitimize business dealing 1979 ...          -0.8591
# 5341  black comedy follows three generation family c...          -0.8020
# 3942  set 1930s honest goodhearted man forced turn l...          -0.8486
# 4597  story group friend turn century new york early...          -0.5859
# 8228  manzoni family notorious mafia clan relocated ...          -0.9022
# 911   true story henry hill halfirish halfsicilian b...          -0.9788
# 6539  john gotti head small new york mafia crew brea...          -0.8481
# 8889  true story whitey bulger brother state senator...          -0.9217

# %%
movie_name = 'Casablanca'
index = df_main[df_main['title'].str.contains(movie_name)].index[0]
result = df_main.loc[[val for val in np.argsort(similarity[index])[::-1][1:11]]]
result
# Out:
#       movie_id                                              title  \
# 4824      7215                        To Have and Have Not (1944)
# 709        930                                   Notorious (1946)
# 7718     91079                                  Like Crazy (2011)
# 6886     64034  Boy in the Striped Pajamas, The (Boy in the St...
# 3582      4920                                Now, Voyager (1942)
# 3784      5304  Rome, Open City (a.k.a. Open City) (Roma, citt...
# 1964      2612                              Mildred Pierce (1945)
# 1536      2074   Night Porter, The (Portiere di notte, Il) (1974)
# 724        946                          To Be or Not to Be (1942)
# 3570      4900                                    Out Cold (2001)
#
#                                     genres  year  tmdb_id    imdb_id  \
# 4824  Adventure|Drama|Romance|Thriller|War  1944    22584  tt0037382
# 709             Film-Noir|Romance|Thriller  1946      303  tt0038787
# 7718                         Drama|Romance  2011    60420  tt1758692
# 6886                             Drama|War  2008    14574  tt0914798
# 3582                         Drama|Romance  1942    32847  tt0035140
# 3784                             Drama|War  1945      307  tt0038890
# 1964                       Drama|Film-Noir  1945     3309  tt0037913
# 1536                   Crime|Drama|Romance  1974    26648  tt0071910
# 724                       Comedy|Drama|War  1942      198  tt0035446
# 3570                                Comedy  2001    14369  tt0253798
#
#       tmdb_rating  tmdb_votes  imdb_rating  imdb_votes  \
# 4824          7.6         112          7.8       34016
# 709           7.8         345          7.9       99434
# 7718          6.5         386          6.6       61336
# 6886          7.7        1492          7.8      210824
# 3582          7.1          30          7.9       16660
# 3784          7.9         123          8.0       25967
# 1964          7.4          81          8.0       25360
# 1536          6.6          53          6.6       12975
# 724           7.7         119          8.2       35640
# 3570          5.8          53          6.2       17495
#
#                                                    body  sentiment_score
# 4824  martinique charter boat skipper get mixed unde...           0.3400
# 709   released shortly war classic hitchcock film il...          -0.6705
# 7718  british college student fall american student ...           0.6705
# 6886  family move home berlin strange new house pola...          -0.9451
# 3582  woman suffers nervous breakdown oppressive mot...           0.8555
# 3784  open city landmark film history filmed secrecy...           0.9001
# 1964  cheating husband leaf mildred pierce prof beco...          -0.0067
# 1536  unsettling drama italian filmmaker liliana cav...          -0.4767
# 724   nazi occupation poland acting troupe becomes e...           0.1779
# 3570  animal house meet casablanca outrageous snowbo...           0.5584

# %% [markdown]
# The content-based recommender works well and makes relevant recommendations. It has recommended drama/crime/mafia movies for Godfather and romance/drama/war movies for Casablanca.

# %% [markdown]
# The `similarity` matrix is a relevance matrix that contains all the movies from the dataset used.

# %%
#Save the similarity matrix as a pickle
pickle.dump(similarity, open('../data/movie_similarity_matrix.pkl', 'wb'))

# %% [markdown]
# Now that we have built a recommendation system that recommends movies based on a movie's content, the next step would be to implement this for a user based on the user's activity or viewing history.

# %%
#Converting the similarity matrix into a dataframe.
df_content_sim = pd.DataFrame(similarity, index=df_main['title'].values, columns=df_main['title'].values)

# %%
df_content_sim.drop_duplicates(inplace=True)

# %%
#Import user database
df_user = pd.read_csv('../data/ratings_title.csv')
df_user
# Out:
#         userId  movieId  rating                             title  \
# 0            1        1     4.0                  Toy Story (1995)
# 1            5        1     4.0                  Toy Story (1995)
# 2            7        1     4.5                  Toy Story (1995)
# 3           15        1     2.5                  Toy Story (1995)
# 4           17        1     4.5                  Toy Story (1995)
# ...        ...      ...     ...                               ...
# 100831     610   160341     2.5                  Bloodmoon (1997)
# 100832     610   160527     4.5  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0                     Hazard (2005)
# 100834     610   163937     3.5                Blair Witch (2016)
# 100835     610   163981     3.5                         31 (2016)
#
#                                              genres  year
# 0       Adventure|Animation|Children|Comedy|Fantasy  1995
# 1       Adventure|Animation|Children|Comedy|Fantasy  1995
# 2       Adventure|Animation|Children|Comedy|Fantasy  1995
# 3       Adventure|Animation|Children|Comedy|Fantasy  1995
# 4       Adventure|Animation|Children|Comedy|Fantasy  1995
# ...                                             ...   ...
# 100831                              Action|Thriller  1997
# 100832                           Action|Crime|Drama  1971
# 100833                        Action|Drama|Thriller  2005
# 100834                              Horror|Thriller  2016
# 100835                                       Horror  2016
#
# [100836 rows x 6 columns]

# %% [markdown]
# As seen below, there are users that have rated 20 movies on one side of the spectrum and 2698 movies on the other side of the spectrum. In order to make it easier to evaluate whether the recommendations make sense, user with 20 movie ratings as been chosen.

# %%
df_user.groupby('userId')['movieId'].count().sort_values()
# Out:
# userId
# 442      20
# 406      20
# 147      20
# 194      20
# 569      20
#        ...
# 274    1346
# 448    1864
# 474    2108
# 599    2478
# 414    2698
# Name: movieId, Length: 610, dtype: int64

# %%
#Movies watched by user 569
df_user[df_user['userId'] == 569]
# Out:
#        userId  movieId  rating                                   title  \
# 760       569       50     3.0              Usual Suspects, The (1995)
# 1480      569      231     3.0  Dumb & Dumber (Dumb and Dumber) (1994)
# 2102      569      296     5.0                     Pulp Fiction (1994)
# 2250      569      316     4.0                         Stargate (1994)
# 2415      569      349     4.0         Clear and Present Danger (1994)
# 2727      569      356     3.0                     Forrest Gump (1994)
# 3405      569      480     4.0                    Jurassic Park (1993)
# 4105      569      590     4.0               Dances with Wolves (1990)
# 4287      569      592     3.0                           Batman (1989)
# 20105     569      588     4.0                          Aladdin (1992)
# 20252     569      595     4.0             Beauty and the Beast (1991)
# 25654     569      153     5.0                   Batman Forever (1995)
# 26134     569      344     4.0       Ace Ventura: Pet Detective (1994)
# 26476     569      380     3.0                        True Lies (1994)
# 27497     569       10     4.0                        GoldenEye (1995)
# 29126     569      165     5.0       Die Hard: With a Vengeance (1995)
# 29398     569      185     4.0                         Net, The (1995)
# 30929     569      329     5.0           Star Trek: Generations (1994)
# 31632     569      377     5.0                            Speed (1994)
# 31926     569      434     4.0                      Cliffhanger (1993)
#
#                                             genres  year
# 760                         Crime|Mystery|Thriller  1995
# 1480                              Adventure|Comedy  1994
# 2102                   Comedy|Crime|Drama|Thriller  1994
# 2250                       Action|Adventure|Sci-Fi  1994
# 2415                   Action|Crime|Drama|Thriller  1994
# 2727                      Comedy|Drama|Romance|War  1994
# 3405              Action|Adventure|Sci-Fi|Thriller  1993
# 4105                       Adventure|Drama|Western  1990
# 4287                         Action|Crime|Thriller  1989
# 20105  Adventure|Animation|Children|Comedy|Musical  1992
# 20252  Animation|Children|Fantasy|Musical|Romance|  1991
# 25654                Action|Adventure|Comedy|Crime  1995
# 26134                                       Comedy  1994
# 26476     Action|Adventure|Comedy|Romance|Thriller  1994
# 27497                    Action|Adventure|Thriller  1995
# 29126                        Action|Crime|Thriller  1995
# 29398                        Action|Crime|Thriller  1995
# 30929                       Adventure|Drama|Sci-Fi  1994
# 31632                      Action|Romance|Thriller  1994
# 31926                    Action|Adventure|Thriller  1993

# %% [markdown]
# The following code takes into account the movies that the user has seen, computes movies related to these movies, ranks them based on relevancy score and recommends them.

# %%
user = 569
def get_content_similarity(user):
    # Current/target user
    df_current_user = df_user[df_user['userId'] == user]

    # Movies watched by target user
    user_watched_movies = df_current_user['title'].values

    # target user's mean rating
    user_mean_rating = df_current_user['rating'].mean()

    # Filter movies liked by user (rating >= mean)
    user_movies = []
    for movie in user_watched_movies:
        if df_current_user[df_current_user['title'] == movie]['rating'].values >= user_mean_rating:
            user_movies.append(movie)

    # Collect similarity rows instead of using append
    rows = []

    for movie in user_movies:
        if movie in df_content_sim.columns:
            sim_row = df_content_sim[movie].drop(user_movies, errors='ignore')
            rows.append(sim_row)

    # If no similarity rows
    if not rows:
        return pd.Series(dtype=float)

    # Concat all similarity rows
    similar_movies = pd.concat(rows, axis=1)

    # Sum similarity scores
    scores = similar_movies.sum(axis=1)

    # Return sorted scores
    return scores.sort_values(ascending=False)

# %%
get_content_similarity(user)[0:11]
# Out:
# Live and Let Die (1973)           0.735419
# Jurassic World (2015)             0.735254
# Return of Jafar, The (1994)       0.719338
# Batman Begins (2005)              0.701195
# Dark Knight Rises, The (2012)     0.675723
# Good Day to Die Hard, A (2013)    0.646282
# Rollercoaster (1977)              0.640893
# Die Hard (1988)                   0.639249
# Live Free or Die Hard (2007)      0.638269
# Patriot Games (1992)              0.632206
# Hurt Locker, The (2008)           0.630690
# dtype: float64

# %% [markdown]
# The movies watched by user `569` fall under a mixed bag of genres.  There are movies from Drama, Crime, Thriller to Children category. Most of the recommendations are movies from franchise like Jurrasic World, Die Hard and Batman. It is obvious to get franchise recommendations due to high similarity scores between their contents. But often times sequels of movies are not as popular as the original ones, and the algorithm does not consider popularity. Overall, the recommender has filtered movies that fall under sci-fi, action, crime and thriller. But the algorithm has not caught comedy or romance. In short, the recommendations are less diverse.

# %% [markdown]
# ### Inferences
#
# This recommendation engine focuses on content of the movies. It considers features like genre, movie synopsis, tagline, keywords, director and cast; and determines the similarity between movies based on these features. This recommender does not need any data from other users and hence can be easily scaled to large number of users. This is mainly bacause the item data (movies) does not grow as rapidly as user data. It is also helpful in recommending niche/less popular items specific to the user's interest. This recommender also solves the problem of cold start for new users, as it is not affected by inadequate ratings data.
#
# While this model has its advantages, it also suffers from a fair share of disadvantages. It relies predominantly on domain knowledge as most of the features are engineered manually. Therefore the model can only be as good as its features. Additionally, it makes recommendations based on the user's existing interests. It is therefore less diverse in regards to recommending new items. It has a limited ability towards expansion. Another disadvantage of this model is that it does not consider the popularity of the recommendations.
